# %% [markdown]
# # Import Required Libraries

# %%
import sys
import os
os.chdir("..")
os.chdir("..")
os.chdir("./src")
# sys.path.append("./src")

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import scipy.io
from tqdm import tqdm
from scipy.stats import invgamma, chi2, t
from WSMBSS import *
from numba import njit
from IPython import display
import pylab as pl
import mne 
from mne.preprocessing import ICA
import warnings
warnings.filterwarnings("ignore")
# np.random.seed(157)
# %load_ext autoreload
# %autoreload 2
notebook_name = 'Antisparse_Copula'

# %% [markdown]
# # Source Generation and Mixing Scenario

# %%
rho = 0.0
N = 500000
NumberofSources = 5
NumberofMixtures = 10

M = NumberofMixtures
r = NumberofSources

SNR = 30 # dB
NoiseAmp = (10 ** (-SNR/20))# * np.sqrt(NumberofSources)

S = generate_correlated_copula_sources(rho = rho, df = 4, n_sources = NumberofSources, size_sources = N , 
                                       decreasing_correlation = True)
S = 2 * S - 1

A = np.random.standard_normal(size=(NumberofMixtures,NumberofSources))
Xn = A @ S
Noisecomp=np.random.randn(A.shape[0],S.shape[1])*np.power(10,-SNR/20)#*INPUT_STD
X=Xn+Noisecomp
SNRinp = 20*np.log10(np.std(Xn)/np.std(Noisecomp))

print("The following is the mixture matrix A")
display_matrix(A)
print("Input SNR is : {}".format(SNRinp))
# Out:
# The following is the mixture matrix A
# $\displaystyle \begin{bmatrix}
#  1.431 & 0.437 & 0.349 & 0.461 & -0.241 & \\
#  0.314 & 0.210 & 2.113 & -0.459 & -0.128 & \\
#  -1.225 & 0.060 & -1.331 & -2.148 & -0.282 & \\
#  0.730 & -1.370 & -0.550 & -0.832 & 0.206 & \\
#  0.307 & -1.327 & 0.630 & 0.067 & 0.151 & \\
#  -0.968 & -0.373 & -0.310 & -0.684 & -0.362 & \\
#  -0.193 & 0.791 & -1.363 & -0.878 & -1.034 & \\
#  1.514 & 0.262 & -0.658 & 0.625 & -1.159 & \\
#  0.448 & -1.060 & -0.921 & -1.332 & -1.959 & \\
#  2.458 & -0.002 & -0.562 & -0.722 & 0.539 & \\
# \end{bmatrix}$
# Input SNR is : 31.938903445252997

# %% [markdown]
# # Visualize Generated Sources and Mixtures

# %%
subplot_1D_signals(S.T[0:100], title = 'Original Signals', figsize = (15.2,9), colorcode = None)
subplot_1D_signals(X.T[0:100], title = 'Mixture Signals', figsize = (15,18), colorcode = None)

# %% [markdown]
# # Algorithm Hyperparameter Selection and Weight Initialization

# %%
debug_iteration_point = 10000
gamma = np.sqrt(1 - 4e-3)

# %% [markdown]
# # Run BSM Algorithm on Mixture Signals

# %%
model = OnlineBSM(s_dim = NumberofSources, x_dim = NumberofMixtures, beta = 1e-6, 
                  gamma = gamma, whiten_input_ = True,
                  neural_OUTPUT_COMP_TOL = 1e-7)

model.fit_batch_antisparse(X = X, n_epochs = 1, neural_dynamic_iterations = 500,
                           neural_lr_start = 0.9, neural_lr_stop = 1e-15, fast_start = True)
# Out:
# 100%|██████████| 500000/500000 [00:58<00:00, 8479.48it/s]

# %% [markdown]
# # Calculate Resulting Component SNRs and Overall SINR

# %%
Wf = model.compute_overall_mapping(return_mapping = True)
Y = Wf @ X
Y_ = signed_and_permutation_corrected_sources(S.T,Y.T)
coef_ = (Y_ * S.T).sum(axis = 0) / (Y_ * Y_).sum(axis = 0)
Y_ = coef_ * Y_

print("Component SNR Values : {}\n".format(snr(S.T, Y_)))

SINRwsm = 10*np.log10(CalculateSINR(Y_.T, S)[0])

print("Overall SINR : {}".format(SINRwsm))
# Out:
# Component SNR Values : [35.93670967 32.24889886 32.9575826  32.50278964 32.34270522]
#
# Overall SINR : 33.00448820748886

# %% [markdown]
# # Vizualize Extracted Signals Compared to Original Sources

# %%
subplot_1D_signals(Y_[0:100], title = 'Extracted Signals (Sign and Permutation Corrected)', figsize = (15.2,9), colorcode = None)
subplot_1D_signals(S.T[0:100], title = 'Original Signals', figsize = (15.2,9), colorcode = None)
