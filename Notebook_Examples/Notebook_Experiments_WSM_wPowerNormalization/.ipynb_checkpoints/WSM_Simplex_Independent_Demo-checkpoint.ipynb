# %% [markdown]
# # Import Required Libraries

# %%
import sys

sys.path.insert(0, "../../src")
import numpy as np
import matplotlib.pyplot as plt
from IPython import display
import pylab as pl

from WSMBSS import *
from general_utils import *
from visualization_utils import *

import warnings

warnings.filterwarnings("ignore")
# np.random.seed(100)
# %load_ext autoreload
# %autoreload 2
notebook_name = "Simplex"

# %% [markdown]
# # Source Generation and Mixing Scenario

# %%
NumberofSources = 5
NumberofMixtures = 10
N = 500000
# https://stackoverflow.com/questions/65154622/sample-uniformly-at-random-from-a-simplex-in-python
S = np.random.exponential(scale=1.0, size=(NumberofSources, int(N)))
S = S / np.sum(S, axis=0)

SNR = 30
A = np.random.randn(NumberofMixtures, NumberofSources)
X = np.dot(A, S)

Xnoisy, NoisePart = addWGN(X, SNR, return_noise=True)

SNRinp = 10 * np.log10(
    np.sum(np.mean((Xnoisy - NoisePart) ** 2, axis=1))
    / np.sum(np.mean(NoisePart**2, axis=1))
)
print("The following is the mixture matrix A")
display_matrix(A)
print("Input SNR is : {}".format(SNRinp))

plt.scatter(S[0, :], S[2, :])
plt.show()
# Out:
# The following is the mixture matrix A
# $\displaystyle \begin{bmatrix}
#  -0.185 & 1.260 & 0.067 & 0.973 & 0.083 & \\
#  0.965 & 0.200 & 2.317 & 0.159 & 1.175 & \\
#  -0.960 & 0.580 & 1.563 & 0.538 & -0.346 & \\
#  0.951 & -0.498 & 1.807 & 0.251 & -1.694 & \\
#  -0.316 & 0.415 & 0.152 & -1.259 & -0.161 & \\
#  -0.301 & 1.909 & 0.337 & 0.605 & 0.130 & \\
#  0.266 & 0.671 & 0.630 & -0.175 & 0.863 & \\
#  -0.034 & 1.085 & -0.940 & -0.423 & -0.505 & \\
#  -1.062 & -0.651 & 1.057 & -2.210 & -0.667 & \\
#  0.882 & -1.292 & 0.339 & -0.003 & 1.588 & \\
# \end{bmatrix}$
# Input SNR is : 29.997636883235934

# %% [markdown]
# # Visualize Generated Sources and Mixtures

# %%
subplot_1D_signals(
    S[:, 0:100], title="Original Signals", figsize=(15.2, 9), colorcode=None
)
subplot_1D_signals(
    X[:, 0:100], title="Mixture Signals", figsize=(15, 18), colorcode=None
)

# %% [markdown]
# # Algorithm Hyperparameter Selection and Weight Initialization

# %%
MUS = 0.1
gammaM_start = [MUS, MUS]
gammaM_stop = [1e-3, 1e-3]
gammaW_start = [MUS, MUS]
gammaW_stop = [1e-3, 1e-3]

OUTPUT_COMP_TOL = 1e-5
MAX_OUT_ITERATIONS = 3000
LayerGains = [1, 1]
LayerMinimumGains = [1, 1]
LayerMaximumGains = [1e6, 1.001]
WScalings = [0.0033, 0.0033]
GamScalings = [1, 1]
zeta = 1e-4
beta = 0.5
muD = [20, 1e-2]

s_dim = S.shape[0]
x_dim = X.shape[0]
h_dim = s_dim
samples = S.shape[1]
# W_HX = np.eye(h_dim, x_dim)
# W_YH = np.eye(s_dim, h_dim)

# OPTIONS FOR synaptic_lr_rule: "constant", "divide_by_log_index", "divide_by_index"
synaptic_lr_rule = "divide_by_log_index"
# OPTIONS FOR neural_loop_lr_rule: "constant", "divide_by_loop_index", "divide_by_slow_loop_index"
neural_loop_lr_rule = "divide_by_slow_loop_index"
synaptic_lr_decay_divider = 1
neural_lr_decay_multiplier = 0.005
hidden_layer_gain = 100

# %% [markdown]
# # Run WSM Algorithm on Mixture Signals

# %%
WSM_INPUT_STD = 0.5
XnoisyWSM = (WSM_INPUT_STD * (Xnoisy / Xnoisy.std(1)[:,np.newaxis]))
debug_iteration_point = 25000

model = OnlineWSMBSS(
                        s_dim=s_dim,
                        x_dim=x_dim,
                        h_dim=h_dim,
                        gammaM_start=gammaM_start,
                        gammaM_stop=gammaM_stop,
                        gammaW_start=gammaW_start,
                        gammaW_stop=gammaW_stop,
                        beta=beta,
                        zeta=zeta,
                        muD=muD,
                        WScalings=WScalings,
#                         W_HX=W_HX,
#                         W_YH=W_YH,
                        DScalings=LayerGains,
                        LayerMinimumGains=LayerMinimumGains,
                        LayerMaximumGains=LayerMaximumGains,
                        neural_OUTPUT_COMP_TOL=OUTPUT_COMP_TOL,
                        set_ground_truth=True,
                        S=S,
                        A=A,
                    )

model.fit_batch_simplex(
                            XnoisyWSM,
                            n_epochs=1,
                            neural_lr_start=0.5,
                            neural_lr_stop=0.2,
                            stlambd_lr=0.05,
#                             use_previous_stlambd=True,
                            synaptic_lr_rule=synaptic_lr_rule,
                            neural_loop_lr_rule=neural_loop_lr_rule,
                            neural_fast_start=True,
                            synaptic_lr_decay_divider=synaptic_lr_decay_divider,
                            neural_lr_decay_multiplier=neural_lr_decay_multiplier,
                            hidden_layer_gain=hidden_layer_gain,
                            debug_iteration_point=debug_iteration_point,
                            shuffle=False,
                            plot_in_jupyter=True,
                        )
# Out:
#  16%|█▌        | 78394/500000 [02:49<15:12, 461.81it/s]
# ---------------------------------------------------------------------------
# LinAlgError                               Traceback (most recent call last)
# Input In [5], in <module>
#       3 debug_iteration_point = 25000
#       5 model = OnlineWSMBSS(
#       6                         s_dim=s_dim,
#       7                         x_dim=x_dim,
#    (...)
#      25                         A=A,
#      26                     )
# ---> 28 model.fit_batch_simplex(
#      29                             XnoisyWSM,
#      30                             n_epochs=1,
#      31                             neural_lr_start=0.5,
#      32                             neural_lr_stop=0.2,
#      33                             stlambd_lr=0.05,
#      34                             use_previous_stlambd=True,
#      35                             synaptic_lr_rule=synaptic_lr_rule,
#      36                             neural_loop_lr_rule=neural_loop_lr_rule,
#      37                             neural_fast_start=True,
#      38                             synaptic_lr_decay_divider=synaptic_lr_decay_divider,
#      39                             neural_lr_decay_multiplier=neural_lr_decay_multiplier,
#      40                             hidden_layer_gain=hidden_layer_gain,
#      41                             debug_iteration_point=debug_iteration_point,
#      42                             shuffle=False,
#      43                             plot_in_jupyter=True,
#      44                         )
#
# File /scratch/users/bbozkurt15/WSM_BlindSourceSeparation/Biologically-Plausible-DetMaxNNs-for-Blind-Source-Separation/Notebook_Examples/Notebook_Experiments_WSM_wPowerNormalization/../../src/WSMBSS.py:2483, in OnlineWSMBSS.fit_batch_simplex(self, X, n_epochs, neural_dynamic_iterations, neural_lr_start, neural_lr_stop, stlambd_lr, use_previous_stlambd, synaptic_lr_rule, neural_loop_lr_rule, neural_fast_start, synaptic_lr_decay_divider, neural_lr_decay_multiplier, hidden_layer_gain, clip_gain_gradients, gain_grads_clipping_multiplier, use_newton_steps_for_gains, shuffle, debug_iteration_point, plot_in_jupyter)
#    2480 h = H[:, idx[i_sample]]
#    2481 neural_OUTPUT_COMP_TOL = self.neural_OUTPUT_COMP_TOL
# -> 2483 h, y, STLAMBD_, _ = self.run_neural_dynamics_simplex_jit(
#    2484                                                         x_current=x_current,
#    2485                                                         h=h,
#    2486                                                         y=y,
#    2487                                                         M_H=M_H,
#    2488                                                         M_Y=M_Y,
#    2489                                                         W_HX=W_HX,
#    2490                                                         W_YH=W_YH,
#    2491                                                         D1=D1,
#    2492                                                         D2=D2,
#    2493                                                         beta=beta,
#    2494                                                         zeta=zeta,
#    2495                                                         neural_dynamic_iterations=neural_dynamic_iterations,
#    2496                                                         lr_start=neural_lr_start,
#    2497                                                         lr_stop=neural_lr_stop,
#    2498                                                         lr_rule=neural_loop_lr_rule,
#    2499                                                         lr_decay_multiplier=neural_lr_decay_multiplier,
#    2500                                                         STLAMBD=STLAMBD,
#    2501                                                         stlambd_lr=stlambd_lr,
#    2502                                                         hidden_layer_gain=hidden_layer_gain,
#    2503                                                         neural_fast_start=neural_fast_start,
#    2504                                                         OUTPUT_COMP_TOL=neural_OUTPUT_COMP_TOL,
#    2505                                                     )
#    2506 if use_previous_stlambd:
#    2507     STLAMBD = STLAMBD_
#
# File ~/.conda/envs/wsm/lib/python3.8/site-packages/numba/np/linalg.py:751, in _check_finite_matrix()
#     749 for v in np.nditer(a):
#     750     if not np.isfinite(v.item()):
# --> 751         raise np.linalg.LinAlgError(
#     752             "Array must not contain infs or NaNs.")
#
# LinAlgError: Array must not contain infs or NaNs.

# %% [markdown]
# # Visualize SNR Convergence of Each Source Component

# %%
mpl.rcParams["xtick.labelsize"] = 18
mpl.rcParams["ytick.labelsize"] = 18
plot_convergence_plot(
    model.SNR_list,
    xlabel="Number of Iterations / {}".format(debug_iteration_point),
    ylabel="SINR (dB)",
    title="SINR Convergence Plot",
    colorcode=None,
    linewidth=1.8,
)

# %% [markdown]
# # Calculate Resulting Component SNRs and Overall SINR

# %%
# Wf = model.compute_overall_mapping(return_mapping=True)
# Y_ = Wf @ XnoisyWSM
# Y_ = model.signed_and_permutation_corrected_sources(S, Y_)
# coef_ = ((Y_ * S).sum(axis=1) / (Y_ * Y_).sum(axis=1)).reshape(-1, 1)
# Y_ = coef_ * Y_

# print("Component SNR Values : {}\n".format(snr_jit(S, Y_)))

# SINRwsm = 10 * np.log10(CalculateSINRjit(Y_, S, False)[0])

# print("Overall SINR : {}".format(SINRwsm))

# %%
Szeromean = S - S.mean(axis=1).reshape(-1, 1)
Wf = model.compute_overall_mapping(return_mapping=True)
Y_ = Wf @ XnoisyWSM
Yzeromean = Y_ - Y_.mean(axis=1).reshape(-1, 1)
Y_ = model.signed_and_permutation_corrected_sources(Szeromean, Yzeromean)
coef_ = ((Y_ * Szeromean).sum(axis=1) / (Y_ * Y_).sum(axis=1)).reshape(-1, 1)
Y_ = coef_ * Y_

print("Component SNR Values : {}\n".format(snr_jit(Szeromean, Y_)))

SINRwsm = 10 * np.log10(CalculateSINRjit(Y_, Szeromean, False)[0])

print("Overall SINR : {}".format(SINRwsm))

# %% [markdown]
# # Vizualize Extracted Signals Compared to Original Sources

# %%
k = 2500
subplot_1D_signals(
    Y_[:, k : k + 100],
    title="Extracted Signals (Sign and Permutation Corrected)",
    figsize=(15.2, 9),
    colorcode=None,
)
subplot_1D_signals(
    S[:, k : k + 100], title="Original Signals", figsize=(15.2, 9), colorcode=None
)

# %%
import mir_eval

# %%
S.shape, Y_.shape

# %%
mir_eval.separation.bss_eval_sources(S, Y_, compute_permutation=True)
