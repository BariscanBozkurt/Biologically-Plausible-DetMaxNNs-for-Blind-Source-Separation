# %% [markdown]
# # Import Required Libraries

# %%
import sys
import os
os.chdir("..")
os.chdir("..")
os.chdir("./src")
# sys.path.append("./src")

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import scipy.io
from tqdm import tqdm
from scipy.stats import invgamma, chi2, t
from WSMBSS import *
from numba import njit
from IPython import display
import pylab as pl
import mne 
from mne.preprocessing import ICA
import warnings
warnings.filterwarnings("ignore")
np.random.seed(753)
# %load_ext autoreload
# %autoreload 2
notebook_name = 'Antisparse_Copula'

# %% [markdown]
# # Source Generation and Mixing Scenario

# %%
rho = 0.6
N = 500000
NumberofSources = 5
NumberofMixtures = 15

M = NumberofMixtures
r = NumberofSources

SNR = 30 # dB

S = generate_correlated_copula_sources(rho = rho, df = 4, n_sources = NumberofSources, size_sources = N , 
                                       decreasing_correlation = False)

nn_components = [4,2]
source_indices = [j for j in range(S.shape[0])]
signed_components = source_indices.copy()
for a in nn_components:
    signed_components.remove(a)
S[signed_components,:] = 2 * S[signed_components, :] - 1

INPUT_STD = np.std(S, axis = 1).mean()
A = np.random.standard_normal(size=(NumberofMixtures,NumberofSources))
X = A @ S
for MM in range(A.shape[0]):
    stdx = np.std(X[MM,:])
    A[MM,:] = A[MM,:]/stdx * INPUT_STD
Xn = A @ S
Noisecomp=np.random.randn(A.shape[0],S.shape[1])*np.power(10,-SNR/20)*INPUT_STD
X=Xn+Noisecomp
SNRinp = 20*np.log10(np.std(Xn)/np.std(Noisecomp))

R = np.corrcoef(S)
print("The following is the mixture matrix A")
display_matrix(A)
print("Input SNR is : {}".format(SNRinp))
print("The following is the Pearson Correlation Matrix")
display_matrix(R)
# Out:
# The following is the mixture matrix A
# $\displaystyle \begin{bmatrix}
#  -0.612 & 0.076 & 0.508 & 0.737 & 0.286 & \\
#  -0.428 & -0.504 & 0.559 & -0.233 & 0.107 & \\
#  -0.332 & -0.484 & -0.825 & 0.525 & -0.040 & \\
#  0.422 & -0.361 & -0.800 & -0.202 & -0.564 & \\
#  0.190 & -0.565 & -1.476 & 0.593 & 0.957 & \\
#  -0.142 & -0.346 & -0.400 & -0.220 & -0.134 & \\
#  0.531 & 0.135 & -0.091 & 0.336 & -0.115 & \\
#  -0.765 & -0.180 & 0.937 & -0.349 & 0.454 & \\
#  0.395 & -0.368 & 0.618 & 0.448 & 0.081 & \\
#  0.437 & 0.001 & 0.533 & 0.266 & -0.071 & \\
#  -0.043 & 0.570 & 0.483 & 0.153 & -0.036 & \\
#  0.703 & -0.843 & 0.315 & 0.381 & -0.286 & \\
#  -0.319 & -0.608 & -0.191 & -0.028 & 0.391 & \\
#  -0.316 & -0.155 & -0.787 & -0.401 & 0.962 & \\
#  0.318 & -0.601 & -1.092 & 0.845 & -0.126 & \\
# \end{bmatrix}$
# Input SNR is : 32.244459040218224
# The following is the Pearson Correlation Matrix
# $\displaystyle \begin{bmatrix}
#  1.000 & 0.568 & 0.568 & 0.567 & 0.566 & \\
#  0.568 & 1.000 & 0.568 & 0.567 & 0.567 & \\
#  0.568 & 0.568 & 1.000 & 0.569 & 0.569 & \\
#  0.567 & 0.567 & 0.569 & 1.000 & 0.568 & \\
#  0.566 & 0.567 & 0.569 & 0.568 & 1.000 & \\
# \end{bmatrix}$

# %% [markdown]
# # Visualize Generated Sources and Mixtures

# %%
subplot_1D_signals(S.T[0:100], title = 'Original Signals', figsize = (15.2,9), colorcode = None)
subplot_1D_signals(X.T[0:100], title = 'Mixture Signals', figsize = (15,18), colorcode = None)

# %% [markdown]
# # Algorithm Hyperparameter Selection and Weight Initialization

# %%
if rho > 0.4:
    MUS = 0.4
    gamma_stop = 1e-4
else:
    MUS = 0.6
    gamma_stop = 1e-3
OUTPUT_COMP_TOL = 1e-6
MAX_OUT_ITERATIONS= 3000
LayerGains = [1,1]
LayerMinimumGains = [0.2,0.5]
LayerMaximumGains = [1e6,5]
WScalings = [0.005,0.005]
GamScalings = [2,1]
zeta = 5*1e-5
beta = 0.5
muD = [1.125, 0.1]

s_dim = S.shape[0]
x_dim = X.shape[0]
h_dim = s_dim
samples = S.shape[1]
W_HX = np.eye(h_dim, x_dim)
W_YH = np.eye(s_dim, h_dim)

# %% [markdown]
# # Run WSM Algorithm on Mixture Signals

# %%
debug_iteration_point = 10000
modelWSM = OnlineWSMBSS(s_dim = s_dim, x_dim = x_dim, h_dim = h_dim, 
                        gamma_start = MUS, gamma_stop = gamma_stop, beta = beta, zeta = zeta, 
                        muD = muD,WScalings = WScalings, GamScalings = GamScalings,
                        W_HX = W_HX, W_YH = W_YH,
                        DScalings = LayerGains, LayerMinimumGains = LayerMinimumGains,
                        LayerMaximumGains = LayerMaximumGains,neural_OUTPUT_COMP_TOL = OUTPUT_COMP_TOL,
                        set_ground_truth = True, S = S, A = A)

modelWSM.fit_batch_mixedantisparse(X, nn_components, n_epochs = 1, 
                                neural_lr_start = 0.75,
                                neural_lr_stop = 0.05,
                                debug_iteration_point = debug_iteration_point,
                                plot_in_jupyter = True,
                                )
# Out:
# 100%|██████████| 500000/500000 [31:42<00:00, 262.80it/s]

# %% [markdown]
# # Visualize SNR Convergence of Each Source Component

# %%
mpl.rcParams['xtick.labelsize'] = 18
mpl.rcParams['ytick.labelsize'] = 18
plot_convergence_plot(modelWSM.SNR_list, xlabel = 'Number of Iterations / {}'.format(debug_iteration_point),
                     ylabel = 'SINR (dB)', title = 'SINR Convergence Plot', colorcode = None, linewidth = 1.8)

# %% [markdown]
# # Calculate Resulting Component SNRs and Overall SINR

# %%
Wf = modelWSM.compute_overall_mapping(return_mapping = True)
Y = Wf @ X
Y_ = signed_and_permutation_corrected_sources(S.T,Y.T)
coef_ = (Y_ * S.T).sum(axis = 0) / (Y_ * Y_).sum(axis = 0)
Y_ = coef_ * Y_

print("Component SNR Values : {}\n".format(snr(S.T, Y_)))

SINRwsm = 10*np.log10(CalculateSINR(Y_.T, S)[0])

print("Overall SINR : {}".format(SINRwsm))
# Out:
# Component SNR Values : [23.79339681 12.63683543 28.43462853 22.27373636 18.80645218]
#
# Overall SINR : 18.106901010819318

# %% [markdown]
# # Vizualize Extracted Signals Compared to Original Sources

# %%
subplot_1D_signals(Y_[0:100], title = 'Extracted Signals (Sign and Permutation Corrected)', figsize = (15.2,9), colorcode = None)
subplot_1D_signals(S.T[0:100], title = 'Original Signals', figsize = (15.2,9), colorcode = None)
